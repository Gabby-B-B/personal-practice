# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer

import warnings
warnings.filterwarnings("ignore")

# %%
by_county= pd.read_excel("california-regions-break-out-by-county.xlsx")
by_region_dict= pd.read_excel("screening-disorders-by-region-data-dictionary.xlsx")
by_race_dict= pd.read_excel("screening-disorders-by-race-ethnicity-data-dictionary.xlsx")
statewide_dict=pd.read_excel("screening-disorders-statewide-data-dictionary.xlsx")
statewide= pd.read_csv("screening-disorders-statewide.csv")
by_region= pd.read_csv("screening-disorders-by-california-region.csv")
by_race= pd.read_csv("screening-disorders-by-race-ethnicity.csv")

# %%
by_county.head()
# Out:
#   California Region Break-Out by County
# 0                           Los Angeles
# 1                        Southern Coast
# 2                                Orange
# 3                             San Diego
# 4                Southern Inland Empire

# %%
by_region_dict.head()
# Out:
#                             COLUMN NAME   FORMAT  \
# 0                     California Region   String
# 1                          Disease Type   String
# 2                            Case Count  Numeric
# 3                       Number Screened  Numeric
# 4  Percent of All Disorders in Region    Percent
#
#                                           DEFINITION
# 0  Defined as: Central Coast, Los Angeles, Northe...
# 1  Names of the disorders diagnosed through the C...
# 2  Count of cases diagnosed through the Californi...
# 3  Number of newborns screened in each respective...
# 4  Percent distribution of diagnosed disorders wi...

# %%
by_race_dict.head()
# Out:
#         COLUMN NAME   FORMAT  \
# 0    Race/Ethnicity   String
# 1     Disorder Type   String
# 2    Disorder Count  Numeric
# 3    Screened Count  Numeric
# 4  Rate per 100,000  Numeric
#
#                                           DEFINITION
# 0  Race/ethnicity category provided by the clinic...
# 1  Names of the disorders diagnosed through the C...
# 2  Count of disorders diagnosed through the Calif...
# 3  Number of newborns screened within each respec...
# 4       (Disorder Count / Screened Count) * 100,000.

# %%
statewide_dict.head()
# Out:
#          COLUMN NAME   FORMAT  \
# 0      Disorder Type   String
# 1              Count  Numeric
# 2            Percent      NaN
# 3  Newborns Screened  Numeric
#
#                                           DEFINITION
# 0  Names of the disorders diagnosed through the C...
# 1  Count of cases diagnosed through the Californi...
# 2  Percent of initial screen positive test result...
# 3  This is the count of newborns screened for the...

# %%
statewide.head()
# Out:
#                                        Disorder Type Disorder\nCount Percent  \
# 0  3-Hydroxy-3-methylglutaryl-CoA lyase deficienc...               .      <1
# 1                 Beta-ketothiolase deficiency (BKT)               .      <1
# 2  Homocystinuria (cystathionine beta-synthase de...               .      <1
# 3                    MPS I - not otherwise specified               .      <1
# 4                           MPS I - severe (Hurlers)               .      <1
#
#    Newborns\nScreened
# 0             5350864
# 1             5350864
# 2             5350864
# 3              643218
# 4              643218

# %%
by_region.head()
# Out:
#   California Region                                       Disease Type  \
# 0     Central Coast  3-Methylcrotonyl-CoA carboxylase deficiency (3...
# 1     Central Coast                      ALD - not otherwise specified
# 2     Central Coast                               ALD carrier (female)
# 3     Central Coast               Biotinidase deficiency profound (BD)
# 4     Central Coast  Carnitine transporter deficiency (CTD)/carniti...
#
#    Case\nCount  Number\nScreened Percent\nof All\nDisorders\nin Region
# 0           19            557240                                     3
# 1           11            185798                                     2
# 2           18            185798                                     3
# 3            7            557240                                     1
# 4           10            557240                                     2

# %%
by_race.head()
# Out:
#     Race/Ethnicity                                      Disorder Type  \
# 0  American Indian                               Cystic fibrosis (CF)
# 1  American Indian           Hypothyroidism, primary congenital (PCH)
# 2  American Indian                                Sickle Cell Disease
# 3     Asian Indian  Carnitine transporter deficiency (CTD)/carniti...
# 4     Asian Indian  Congenital adrenal hyperplasia, classical salt...
#
#    Disorder\nCount  Screened\nCount  Rate\nper\n100,000
# 0                9            52784               17.05
# 1               25            52784               47.36
# 2                8            52784               15.16
# 3               10           124895                8.01
# 4                6           124895                4.80
